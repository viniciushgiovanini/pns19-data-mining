# %% [markdown]
# ### Leitura do dataset

# %%
from lib.view import Explorer

exp = Explorer("./data/dicionario_PNS_microdados_2019.xls")
exp.print_module_len()
# Out:
# Modulo: C tem 18 atributos
# Modulo: D tem 18 atributos
# Modulo: F tem 4 atributos
# Modulo: I tem 14 atributos
# Modulo: J tem 64 atributos
# Modulo: P tem 143 atributos
# Modulo: Q tem 236 atributos
# Total: 497

# %%
exp.print_variables_per_module()
# Out:
# Modulo: C
#
# Condição no domicílio | C004
#
# Sexo | C006
#
# Dia de nascimento | C00701
#
# Mês de nascimento | C00702
#
# Ano de nascimento | C00703
#
# Idade do morador na data de referência | C008
#
# Cor ou raça | C009
#
# Cônjuge ou companheiro(a) mora em nesse domicílio. | C01001
#
# Número de ordem do cônjuge ou companheiro(a) | C010010
#
# Cônjuge ou companheiro(a) mora em outro domicílio. | C013
#
# Qual é a natureza dessa união?  | C014
#
# Esta união é registrada em cartório?  | C015
#
# Foi realizada cerimônia religiosa para esta união?  | C016
#
# ___já viveu com cônjuge ou companheiro (a) antes?  | C017
#
# Que idade ___tinha quando começou a viver com seu(sua) primeiro(a)/único(a) marido (mulher) ou companheiro(a)?   | C018
#
# Que idade ___tinha quando começou a viver com seu(sua) primeiro(a)/único(a) marido (mulher) ou companheiro(a)?    | C01801
#
# Qual é o estado civil de ___?  | C011
#
# Informante do Módulo C | C012
#
#
#  ---X---
#
# Modulo: D
#
# ...

# %%
exp.load_variables("./data/my_variables_v2.pkl")
exp.print_module_len()
# Out:
# Modulo: C tem 4 atributos
# Modulo: D tem 4 atributos
# Modulo: F tem 3 atributos
# Modulo: I tem 12 atributos
# Modulo: J tem 19 atributos
# Modulo: N tem 1 atributos
# Modulo: P tem 37 atributos
# Modulo: Q tem 11 atributos
# Total: 91

# %%
exp.print_variables_per_module()
# Out:
# Modulo: C
#
# Sexo | C006
#
# Idade do morador na data de referência | C008
#
# Cor ou raça | C009
#
# Qual é o estado civil de ___?  | C011
#
#
#  ---X---
#
# Modulo: D
#
# Sabe ler e escrever | D001
#
# Frequenta escola ou creche | D00201
#
# Qual foi o curso mais elevado que ___frequentou  | D00901
#
# ___concluiu este curso que frequentou  | D014
#
#
#  ---X---
#
# Modulo: F
#
# Em (mês da pesquisa) ___ recebia normalmente rendimento de aposentadoria ou pensão de instituto de previdência federal (INSS), estadual, municipal, ou do governo federal, estadual, municipal? | F001011
#
# Em (mês da pesquisa), ___ recebia normalmente rendimento de pensão alimentícia, doação ou mesada em dinheiro de pessoa que não morava no domicílio? | F007011
#
# Em (mês da pesquisa), ___ recebia normalmente rendimento de aluguel ou arrendamento? | F008011
#
#
#  ---X---
#
# Modulo: I
#
# tem algum plano odontológico particular, de empresa ou órgão público? | I00101
#
# ...

# %%
lista_col = ['Unidade da Federação',
 'Sexo',
 'Idade do morador na data de referência',
 'Cor ou raça',
 'Qual é o estado civil de ___? ',
 'Sabe ler e escrever',
 'Frequenta escola ou creche',
 'Qual foi o curso mais elevado que ___frequentou ',
 '___concluiu este curso que frequentou ',
 'Em (mês da pesquisa) ___ recebia normalmente rendimento de aposentadoria ou pensão de instituto de previdência federal (INSS), estadual, municipal, ou do governo federal, estadual, municipal?',
 'Em (mês da pesquisa), ___ recebia normalmente rendimento de pensão alimentícia, doação ou mesada em dinheiro de pessoa que não morava no domicílio?',
 'Em (mês da pesquisa), ___ recebia normalmente rendimento de aluguel ou arrendamento?',
 'tem algum plano odontológico particular, de empresa ou órgão público?',
 'tem algum plano de saúde médico particular, de empresa ou órgão público?',
 'De um modo geral, como é o estado de saúde de________',
 'Considerando saúde como um estado de bem-estar físico e mental, e não somente a ausência de doenças, como é o estado de saúde de _____________? ',
 ' Nas duas últimas semanas, ___ deixou de realizar quaisquer de suas atividades habituais (trabalhar, ir à escola, brincar, afazeres domésticos etc.) por motivo da própria saúde',
 'Algum médico já deu o diagnóstico de alguma doença crônica, física ou mental, ou doença de longa duração (de mais de 6 meses de duração) a ___',
 'Alguma dessas doenças limita de alguma forma suas atividades habituais (trabalhar, ir à escola, brincar, afazeres domésticos, etc.)',
 ' ___ costuma procurar o mesmo lugar, mesmo médico ou mesmo serviço de saúde quando precisa de atendimento de saúde',
 'Quando está doente ou precisando de atendimento de saúde___ costuma procurar',
 'Quando ____ consultou um médico pela última vez',
 'Quando ___ consultou um dentista pela última vez',
 'Nas duas últimas semanas, ___ procurou algum lugar, serviço ou profissional de saúde para atendimento relacionado à própria saúde',
 'Em geral, como o(a) Sr(a) avalia a sua saúde',
 'O(A) Sr(a) sabe seu peso? ',
 'Peso - Informado (em kg)\n(3 inteiros e 1 casa decimal)',
 'O(A) Sr(a) sabe sua altura? (mesmo que seja valor aproximado) ',
 'Altura - Informada (em cm)\n(3 inteiros)',
 'Em quantos dias da semana o(a) Sr(a) costuma comer feijão? ',
 'Em quantos dias da semana, o(a) Sr(a) costuma comer pelo menos um tipo de verdura ou legume (sem contar batata, mandioca, cará ou inhame) como alface, tomate, couve, cenoura, chuchu, berinjela, abobrinha? ',
 'Em quantos dias da semana o(a) Sr(a) costuma comer carne vermelha (boi, porco, cabrito, bode, ovelha etc.)? ',
 'Em quantos dias da semana o(a) Sr(a) costuma comer frango/galinha? ',
 'Em quantos dias da semana o(a) Sr(a) costuma comer peixe? ',
 'Em quantos dias da semana o(a) Sr(a) costuma tomar refrigerante? ',
 'Em quantos dias da semana o(a) Sr(a) costuma tomar suco de caixinha/lata ou refresco em pó ? ',
 'Em quantos dias da semana o(a) Sr(a) costuma tomar suco de fruta natural (incluída a polpa de fruta congelada)? ',
 'Em quantos dias da semana o(a) Sr(a) costuma comer frutas? ',
 'Em quantos dias da semana o(a) Sr(a) costuma tomar leite? (de origem animal: vaca, cabra, búfala etc.) ',
 'Que tipo de leite o(a) Sr(a) costuma tomar? ',
 'Em quantos dias da semana o(a) Sr(a) costuma comer alimentos doces como biscoito/bolacha recheado, chocolate, gelatina, balas e outros?',
 'Em quantos dias da semana o(a) Sr(a) costuma substituir a refeição do almoço por lanches rápidos como sanduíches, salgados, pizza, cachorro quente, etc? ',
 'Considerando a comida preparada na hora e os alimentos industrializados, o(a) Sr(a) acha que o seu consumo de sal é:',
 'Nos últimos três meses, o(a) Sr(a) praticou algum tipo de exercício físico ou esporte? ',
 'Com que frequência o(a) Sr(a) costuma consumir alguma bebida alcoólica?',
 'Algum médico já lhe deu o diagnóstico de hipertensão arterial (pressão alta)? ',
 'Algum médico já lhe deu o diagnóstico de diabetes? ',
 'Quando foi a última vez que o(a) Sr(a) fez exame de sangue para medir a glicemia, isto é, o açúcar no sangue? ']

exp.add_variables_by_description(lista_col)
exp.print_module_len()
len(lista_col)

lista_col2 = ['Unidade da Federação', 'Em geral, como o(a) Sr(a) avalia a sua saúde', 'Sexo', 'Idade do morador na data de referência', 'Cor ou raça', 'Qual é o estado civil de ___? ', 'Sabe ler e escrever', 'Frequenta escola ou creche', 'Qual foi o curso mais elevado que ___frequentou ', '___concluiu este curso que frequentou ', 'Em (mês da pesquisa) ___ recebia normalmente rendimento de aposentadoria ou pensão de instituto de previdência federal (INSS), estadual, municipal, ou do governo federal, estadual, municipal?', 'Em (mês da pesquisa), ___ recebia normalmente rendimento de pensão alimentícia, doação ou mesada em dinheiro de pessoa que não morava no domicílio?', 'Em (mês da pesquisa), ___ recebia normalmente rendimento de aluguel ou arrendamento?', 'tem algum plano odontológico particular, de empresa ou órgão público?', 'tem algum plano de saúde médico particular, de empresa ou órgão público?', ' Nas duas últimas semanas, ___ deixou de realizar quaisquer de suas atividades habituais (trabalhar, ir à escola, brincar, afazeres domésticos etc.) por motivo da própria saúde', 'Algum médico já deu o diagnóstico de alguma doença crônica, física ou mental, ou doença de longa duração (de mais de 6 meses de duração) a ___', 'Alguma dessas doenças limita de alguma forma suas atividades habituais (trabalhar, ir à escola, brincar, afazeres domésticos, etc.)', ' ___ costuma procurar o mesmo lugar, mesmo médico ou mesmo serviço de saúde quando precisa de atendimento de saúde', 'Quando está doente ou precisando de atendimento de saúde___ costuma procurar', 'Quando ____ consultou um médico pela última vez', 'Quando ___ consultou um dentista pela última vez', 'Nas duas últimas semanas, ___ procurou algum lugar, serviço ou profissional de saúde para atendimento relacionado à própria saúde', 'Peso - Informado (em kg)\n(3 inteiros e 1 casa decimal)', 'Altura - Informada (em cm)\n(3 inteiros)', 'Em quantos dias da semana o(a) Sr(a) costuma comer feijão? ', 'Em quantos dias da semana, o(a) Sr(a) costuma comer pelo menos um tipo de verdura ou legume (sem contar batata, mandioca, cará ou inhame) como alface, tomate, couve, cenoura, chuchu, berinjela, abobrinha? ', 'Em quantos dias da semana o(a) Sr(a) costuma comer carne vermelha (boi, porco, cabrito, bode, ovelha etc.)? ', 'Em quantos dias da semana o(a) Sr(a) costuma comer frango/galinha? ', 'Em quantos dias da semana o(a) Sr(a) costuma comer peixe? ', 'Em quantos dias da semana o(a) Sr(a) costuma tomar refrigerante? ', 'Em quantos dias da semana o(a) Sr(a) costuma tomar suco de caixinha/lata ou refresco em pó ? ', 'Em quantos dias da semana o(a) Sr(a) costuma tomar suco de fruta natural (incluída a polpa de fruta congelada)? ', 'Em quantos dias da semana o(a) Sr(a) costuma comer frutas? ', 'Em quantos dias da semana o(a) Sr(a) costuma tomar leite? (de origem animal: vaca, cabra, búfala etc.) ', 'Que tipo de leite o(a) Sr(a) costuma tomar? ', 'Em quantos dias da semana o(a) Sr(a) costuma comer alimentos doces como biscoito/bolacha recheado, chocolate, gelatina, balas e outros?', 'Em quantos dias da semana o(a) Sr(a) costuma substituir a refeição do almoço por lanches rápidos como sanduíches, salgados, pizza, cachorro quente, etc? ', 'Considerando a comida preparada na hora e os alimentos industrializados, o(a) Sr(a) acha que o seu consumo de sal é:', 'Nos últimos três meses, o(a) Sr(a) praticou algum tipo de exercício físico ou esporte? ', 'Com que frequência o(a) Sr(a) costuma consumir alguma bebida alcoólica?', 'Algum médico já lhe deu o diagnóstico de hipertensão arterial (pressão alta)? ', 'Algum médico já lhe deu o diagnóstico de diabetes? ', 'Quando foi a última vez que o(a) Sr(a) fez exame de sangue para medir a glicemia, isto é, o açúcar no sangue? ']
exp.add_variables_by_description(lista_col2)
exp.print_module_len()
len(lista_col2)
# Out:
# Descrição não encontrada: Unidade da Federação
# Descrição não encontrada: Em geral, como o(a) Sr(a) avalia a sua saúde
# Variáveis adicionadas com sucesso!
# Modulo: C tem 4 atributos
# Modulo: D tem 4 atributos
# Modulo: F tem 3 atributos
# Modulo: I tem 2 atributos
# Modulo: J tem 10 atributos
# Modulo: P tem 20 atributos
# Modulo: Q tem 3 atributos
# Total: 46
# Descrição não encontrada: Unidade da Federação
# Descrição não encontrada: Em geral, como o(a) Sr(a) avalia a sua saúde
# Variáveis adicionadas com sucesso!
# Modulo: C tem 4 atributos
# Modulo: D tem 4 atributos
# Modulo: F tem 3 atributos
# Modulo: I tem 2 atributos
# Modulo: J tem 8 atributos
# Modulo: P tem 18 atributos
# Modulo: Q tem 3 atributos
# Total: 42
# 44

# %%
exp.print_variables_per_module()
# Out:
# Modulo: C
#
# Sexo | C006
#
# Idade do morador na data de referência | C008
#
# Cor ou raça | C009
#
# Qual é o estado civil de ___?  | C011
#
#
#  ---X---
#
# Modulo: D
#
# Sabe ler e escrever | D001
#
# Frequenta escola ou creche | D00201
#
# Qual foi o curso mais elevado que ___frequentou  | D00901
#
# ___concluiu este curso que frequentou  | D014
#
#
#  ---X---
#
# Modulo: F
#
# Em (mês da pesquisa) ___ recebia normalmente rendimento de aposentadoria ou pensão de instituto de previdência federal (INSS), estadual, municipal, ou do governo federal, estadual, municipal? | F001011
#
# Em (mês da pesquisa), ___ recebia normalmente rendimento de pensão alimentícia, doação ou mesada em dinheiro de pessoa que não morava no domicílio? | F007011
#
# Em (mês da pesquisa), ___ recebia normalmente rendimento de aluguel ou arrendamento? | F008011
#
#
#  ---X---
#
# Modulo: I
#
# tem algum plano odontológico particular, de empresa ou órgão público? | I00101
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel("./data/dicionario_PNS_microdados_2019.xls", skiprows=1)

# %%
len(df)
# Out:
# 5222

# %%
df.head(10)
# Out:
#                      Posição inicial   Tamanho Código\nda\nvariável Quesito  \
# 0                                 NaN      NaN                  NaN      nº
# 1                                 NaN      NaN                  NaN     NaN
# 2  Parte 1 - Identificação e Controle      NaN                  NaN     NaN
# 3                                   1      2.0                V0001     NaN
# 4                                 NaN      NaN                  NaN     NaN
# 5                                 NaN      NaN                  NaN     NaN
# 6                                 NaN      NaN                  NaN     NaN
# 7                                 NaN      NaN                  NaN     NaN
# 8                                 NaN      NaN                  NaN     NaN
# 9                                 NaN      NaN                  NaN     NaN
#
#              Unnamed: 4 Categorias Unnamed: 6
# 0             descrição      Tipo   Descrição
# ...

# %%
df = df.drop_duplicates().dropna(axis=0)

# %%
len(df)
# Out:
# 1029

# %%
df.head(10)
# Out:
#     Posição inicial   Tamanho Código\nda\nvariável Quesito  \
# 62                35      1.0                 A001      A1
# 67                36      1.0              A002010     A2a
# 75                37      1.0              A003010     A3a
# 83                38      1.0              A004010     A4a
# 90                39      2.0               A01001    A10a
# 93                41      2.0                 A011     A11
# 96                43      1.0              A005010     A5a
# 104               44      1.0              A005012     A5b
# 108               45      1.0               A00601     A6a
# 113               46      1.0              A009010     A9a
#
#                                             Unnamed: 4 Categorias  \
# 62                                   Tipo do domicílio          1
# 67   Qual é o material que predomina na construção ...          1
# 75   Material predominante na cobertura (telhado) d...          1
# ...

# %% [markdown]
# ### Filtrando
#
# - Módulo A – Informações do domicílio
# - Módulo B – Visitas domiciliares de Equipe de Saúde da Família e Agentes de Endemias
# - **Módulo C – Características gerais dos moradores**
# - **Módulo D – Características de educação das pessoas de 5 anos ou mais de idade**
# - Módulo E – Trabalho dos moradores do domicílio
# - **Módulo F – Rendimentos domiciliares**
# - Módulo G – Pessoas com deficiências
# - **Módulo I – Cobertura de plano de saúde**
# - **Módulo J – Utilização de serviços de saúde**
# - Módulo K – Saúde dos indivíduos com 60 anos ou mais e cobertura de mamografia entre mulheres de 50 anos ou mais
# - Módulo L – Crianças com menos de 2 anos
# - Módulo M – Outras características do trabalho e apoio social
# - **Módulo N – Percepção do estado de saúde**
# - Módulo O – Acidentes e violências
# - **Módulo P – Estilos de vida**
# - **Módulo Q – Doenças crônicas**
# - Módulo R – Saúde da mulher
# - Módulo S – Atendimento pré-natal
# - Módulo U – Saúde bucal
# - Módulo X – Atendimento médico

# %% [markdown]
# Renomeando Header

# %%
new_columns = {"Código\nda\nvariável":"Código da Váriavel", "Unnamed: 4" : "Quesito - Descrição", "Quesito": "Quesito - N°", "Categorias": "Categorias - Tipo", "Unnamed: 6" : "Categorias - Descrição"}
df = df.rename(columns=new_columns)
df.head(10)
# Out:
#     Posição inicial   Tamanho Código da Váriavel Quesito - N°  \
# 62                35      1.0               A001           A1
# 67                36      1.0            A002010          A2a
# 75                37      1.0            A003010          A3a
# 83                38      1.0            A004010          A4a
# 90                39      2.0             A01001         A10a
# 93                41      2.0               A011          A11
# 96                43      1.0            A005010          A5a
# 104               44      1.0            A005012          A5b
# 108               45      1.0             A00601          A6a
# 113               46      1.0            A009010          A9a
#
#                                    Quesito - Descrição Categorias - Tipo  \
# 62                                   Tipo do domicílio                 1
# 67   Qual é o material que predomina na construção ...                 1
# ...

# %% [markdown]
# Filtrando o dataset por Módulos

# %%
df_my_categories = df[df["Quesito - N°"].str.startswith(("C", "D", "F", "I", "J", "P", "Q", "N"))]
print(f"Quantidade de elementos: {len(df_my_categories)}")
# Out:
# Quantidade de elementos: 513

# %%
df_my_categories.head(10)
# Out:
#     Posição inicial   Tamanho Código da Váriavel Quesito - N°  \
# 277              106      2.0               C004           C4
# 297              108      1.0               C006           C6
# 300              109      2.0             C00701           C7
# 303              111      2.0             C00702           C7
# 306              113      4.0             C00703           C7
# 309              117      3.0               C008           C8
# 311              120      1.0               C009           C9
# 318              121      1.0             C01001         C10a
# 322              122      2.0            C010010         C10a
# 327              124      1.0               C013          C13
#
#                                    Quesito - Descrição  \
# 277                              Condição no domicílio
# 297                                               Sexo
# 300                                  Dia de nascimento
# 303                                  Mês de nascimento
# ...

# %% [markdown]
# Todas as varaiveis

# %%
all_descriptions = df_my_categories["Quesito - Descrição"]
for row in all_descriptions:
  print(row)
# Out:
# Condição no domicílio
# Sexo
# Dia de nascimento
# Mês de nascimento
# Ano de nascimento
# Idade do morador na data de referência
# Cor ou raça
# Cônjuge ou companheiro(a) mora em nesse domicílio.
# Número de ordem do cônjuge ou companheiro(a)
# Cônjuge ou companheiro(a) mora em outro domicílio.
# Qual é a natureza dessa união?
# Esta união é registrada em cartório?
# Foi realizada cerimônia religiosa para esta união?
# ___já viveu com cônjuge ou companheiro (a) antes?
# Que idade ___tinha quando começou a viver com seu(sua) primeiro(a)/único(a) marido (mulher) ou companheiro(a)?
# Que idade ___tinha quando começou a viver com seu(sua) primeiro(a)/único(a) marido (mulher) ou companheiro(a)?
# Qual é o estado civil de ___?
# Informante do Módulo C
# Sabe ler e escrever
# Frequenta escola ou creche
# A escola que frequenta é da
# Qual é o curso que frequenta
#  Esse curso que ___ frequenta é dividido em
# Qual é o ano/semestre/série que ___frequenta?
# ...

# %% [markdown]
# Filtrando atributos por modulos

# %%
# "C", "D", "F", "I", "J", "P", "Q"
atributos_por_modulos = {
  "C": [],
  "D": [],
  "F": [],
  "I": [],
  "J": [],
  "N": [],
  "P": [],
  "Q": [],
}

for row in df_my_categories.itertuples():
    index_atr = row[3]
    atributos_por_modulos[index_atr[0]].append(row)   
  

total = 0
for mod, values in atributos_por_modulos.items():
  print(f"Modulo: {mod} tem {len(values)} atributos")
  total += len(values)
print(f"Total: {total}")
# Out:
# Modulo: C tem 18 atributos
# Modulo: D tem 18 atributos
# Modulo: F tem 4 atributos
# Modulo: I tem 14 atributos
# Modulo: J tem 64 atributos
# Modulo: N tem 16 atributos
# Modulo: P tem 143 atributos
# Modulo: Q tem 236 atributos
# Total: 513

# %% [markdown]
# Filtrando por Atributos

# %%
from lib.utils import save_variables


atributos_manter = {
  "C":  ["C006", "C008", "C009", "C011"],
  "D": ["D001", "D00201", "D00901", "D014"],
  "F": ["F001011", "F007011", "F008011"],
  "I": ["I00101", "I00102", "I001021", "I00103", "I005", "I006", "I004", "I00401", "I00402", "I00403", "I00404", "I010010"],
  "J": ["J002","J003","J00402","J00404","J005", "J006","J007","J00801","J009","J01002","J01101","J01301","J014","J01502","J01602", "J01701", "J01802", "J019", "J02002",],
  "N": ["N001"],
  "P": ["P00103","P00403", "P006","P00901","P01001","P01101","P013","P015","P02002","P02102","P02001","P01601","P018","P019","P023","P02401","P02501","P02602","P02601","P034","P035","P03701","P03702","P036","P038","P039","P03904","P03905","P040","P04001","P04101", "P04102" ,"P027","P02801","P029","P03202","P03001"],
  "Q": ["Q00201","Q00401","Q00502", "Q010","Q015","Q00601", "Q03001","Q03802", "Q03801", "Q028", "Q02901"]
}
save_variables("./data/my_variables_v2.pkl", atributos_manter)

# %%
todas = []
duplicatas = []

for categoria, lista in atributos_manter.items():
    for item in lista:
        if item in todas and item not in duplicatas:
            duplicatas.append(item)
        todas.append(item)

if duplicatas:
    print("Strings duplicadas encontradas:")
    for d in duplicatas:
        print(" -", d)
else:
    print("Nenhuma string repetida encontrada!")
# Out:
# Nenhuma string repetida encontrada!

# %%
total = 0
for mod, values in atributos_manter.items():
  print(f"Modulo: {mod} tem {len(values)} atributos")
  total += len(values)
print(f"Total: {total}")
# Out:
# Modulo: C tem 4 atributos
# Modulo: D tem 4 atributos
# Modulo: F tem 3 atributos
# Modulo: I tem 12 atributos
# Modulo: J tem 21 atributos
# Modulo: N tem 1 atributos
# Modulo: P tem 39 atributos
# Modulo: Q tem 11 atributos
# Total: 95
